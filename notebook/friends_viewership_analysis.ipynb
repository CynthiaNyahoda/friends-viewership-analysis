# %%
import pandas as pd

# Season-wise Friends viewership data (simplified)
data = {
    "Season": list(range(1, 11)),
    "Number of Episodes": [24, 24, 25, 24, 24, 25, 24, 24, 24, 18],
    "Average Viewers (millions)": [24.3, 29.4, 25.0, 24.7, 23.5, 20.7, 21.6, 24.5, 21.6, 22.8]
}

df = pd.DataFrame(data)
df.to_csv("../data/friends_viewership.csv", index=False)
df
# Out:
# /var/folders/11/1z2rlbps68d_flh4dt29lm100000gq/T/ipykernel_12608/3098613798.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    Season  Number of Episodes  Average Viewers (millions)
# 0       1                  24                        24.3
# 1       2                  24                        29.4
# 2       3                  25                        25.0
# 3       4                  24                        24.7
# 4       5                  24                        23.5
# 5       6                  25                        20.7
# 6       7                  24                        21.6
# 7       8                  24                        24.5
# 8       9                  24                        21.6
# 9      10                  18                        22.8

# %% [markdown]
# # Loading & Describing Data

# %%
# Load the data
df = pd.read_csv("../data/friends_viewership.csv")

# Show first few rows and summary
df.head()
# Out:
#    Season  Number of Episodes  Average Viewers (millions)
# 0       1                  24                        24.3
# 1       2                  24                        29.4
# 2       3                  25                        25.0
# 3       4                  24                        24.7
# 4       5                  24                        23.5

# %% [markdown]
# # Basic Statistics

# %%
total_episodes = df["Number of Episodes"].sum()
avg_viewers = df["Average Viewers (millions)"].mean()

print(f"Total number of episodes: {total_episodes}")
print(f"Average viewers across all seasons: {avg_viewers:.2f} million")
# Out:
# Total number of episodes: 236
# Average viewers across all seasons: 23.81 million

# %% [markdown]
# # Plot ViewerShip Overtime

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.lineplot(x="Season", y="Average Viewers (millions)", data=df, marker="o")
plt.title("Friends Viewership Over Seasons")
plt.xlabel("Season")
plt.ylabel("Average Viewers (millions)")
plt.tight_layout()
plt.savefig("../images/viewership_over_time.png")
plt.show()

# %% [markdown]
# # Plot Viewership Changes

# %%
df["Change in Viewership"] = df["Average Viewers (millions)"].diff()

plt.figure(figsize=(10,6))
sns.barplot(x="Season", y="Change in Viewership", data=df, palette="coolwarm")
plt.title("Change in Viewership Between Seasons")
plt.axhline(0, color="black", linestyle="--")
plt.tight_layout()
plt.savefig("../images/viewership_change.png")
plt.show()
# Out:
# /var/folders/11/1z2rlbps68d_flh4dt29lm100000gq/T/ipykernel_12608/3882235818.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Season", y="Change in Viewership", data=df, palette="coolwarm")
